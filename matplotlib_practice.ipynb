# %%
# %matplotlib inline

# %%
from matplolib import pyplot

# %%
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create the plot
plt.plot(x_axis,y_axis)

# %%
#create the plot with ax.plt()
fig, ax=plt.subplot()

# %%
fig, ax=plt.subplots()
ax.plt(x_axis,y_axis)

# %%
fig, ax=plt.subplots()
ax.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis,y_axis)

# %%
ax.plot(x_axis, y_axis)

# %%
fig=plt.figure()

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
#create a plot and add a lable for the legend

plt.plot(x_axis,y_axis, label="Boston")

# %%
#add lables to x-axis and y-axis
plt.xlabel("Dates")
plt.ylabel("Fares($)")
# Out:
# Text(0, 0.5, 'Fares($)')

# %%
#set y_axis limitations between 0-45
plt.ylim(0, 45)
# Out:
# (0.0, 45.0)

# %%
#create a title 
plt.title("PyBer Fare by Month")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#add legend
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
#create the plot
plt.plot(x_axis, y_axis, color="green", marker="*", linewidth=4, label="Boston")
#create lable for x and y Axes
plt.xlabel("Dates")
plt.ylabel("Fares($)")
#set the limit for y_axis between 0-45
plt.ylim(0,45)
plt.title("PyBar Fare by Month")
#add a grid
plt.grid()
#add a legend
plt.legend()

# %%
# %matplotlib inline
from matplotlib import pyplot
import matplotlib.pyplot as plt


# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>
